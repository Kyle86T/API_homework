# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint
import openweathermapy.core as owm
from citipy import citipy
import gmaps
import os
import json
import requests
from datetime import datetime
from config import api_key
from config2 import google_api_key

# %%
#Part I
# Set n to equal how many times to run the loop
# Need 500 random cities, and some may not have data, so I added an extra 100.
n = 600
cities = []
country_codes = []

for x in range(n):
    lat = np.random.uniform(-90, 90)
    lng = np.random.uniform(-180, 180)
    city = citipy.nearest_city(lat, lng)
    
# Make sure that the randomly generated city is not already in our series
# If it is, regenerate the lat and lng until we get one that isn't
    while city.city_name in cities:
        lat = np.random.uniform(-90, 90)
        lng = np.random.uniform(-180, 180)
        city = citipy.nearest_city(lat, lng)
    
    # Add the data to our lists
    cities.append(city.city_name)
    country_codes.append(city.country_code)
    
country_codes = [x.upper() for x in country_codes]

# %%
# Create base URL and indicate imperial units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# Build partial query URL
query = f"{url}appid={api_key}&units={units}&q="

# %%
# Create an "extracts" object to get the temperature, humidity, cloudiness and wind speed
latitude = []
longitude = []
temperature = []
humidity = []
cloudiness = []
wind_speed = []
dates = []

for x in range(len(cities)):
    response = requests.get(f"{query}{cities[x]},{country_codes[x].upper()}").json()
    
# Some of the cities we generate don't have data in openweathermap, so set their values to numpy's NaN
    try:
        temperature.append(response['main']['temp_max'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        dates.append(response['dt'])
    except KeyError:
        temperature.append(np.nan)
        latitude.append(np.nan)
        longitude.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        dates.append(np.nan)
    
#If there are no clouds for a city, it will provide us a null value, so we want to set those to 0.
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        cloudiness.append(0)
        
# Print each response   
    print(f"Processing record {x + 1} | {cities[x]}")
    print(f"{query}{cities[x]},{country_codes[x].upper()}")

print("Done!")

# Create our Dataframe
weather_df = pd.DataFrame({"City": cities,
                           "Latitude": latitude,
                           "Longitude": longitude,
                           "Humidity": humidity,
                           "Max Temp": temperature,
                           "Cloudiness": cloudiness,
                           "Wind Speed": wind_speed,
                           "Date": dates,
                           "Country": country_codes
                          })
# Out:
# Processing record 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=qaanaaq,GL
# Processing record 2 | dzhusaly
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=dzhusaly,KZ
# Processing record 3 | hede
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hede,CN
# Processing record 4 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=carnarvon,AU
# Processing record 5 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bluff,NZ
# Processing record 6 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tuatapere,NZ
# Processing record 7 | yenangyaung
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=yenangyaung,MM
# Processing record 8 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=punta arenas,CL
# Processing record 9 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kununurra,AU
# Processing record 10 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bambous virieux,MU
# Processing record 11 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=karratha,AU
# Processing record 12 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=luderitz,NA
# Processing record 13 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vaitupu,WF
# Processing record 14 | saleaula
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=saleaula,WS
# Processing record 15 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=torbay,CA
# Processing record 16 | gornyak
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=gornyak,UA
# Processing record 17 | asau
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=asau,TV
# Processing record 18 | kizukuri
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kizukuri,JP
# Processing record 19 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=georgetown,SH
# Processing record 20 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=saint george,BM
# Processing record 21 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tsihombe,MG
# Processing record 22 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=yellowknife,CA
# Processing record 23 | dedovichi
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=dedovichi,RU
# Processing record 24 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=avarua,CK
# Processing record 25 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=saint-philippe,RE
# Processing record 26 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=pangnirtung,CA
# Processing record 27 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=esperance,AU
# Processing record 28 | rungata
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=rungata,KI
# Processing record 29 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=butaritari,KI
# Processing record 30 | burnie
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=burnie,AU
# Processing record 31 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=rikitea,PF
# Processing record 32 | kabare
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kabare,CD
# Processing record 33 | omboue
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=omboue,GA
# Processing record 34 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=khatanga,RU
# Processing record 35 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hofn,IS
# Processing record 36 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=salalah,OM
# Processing record 37 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=airai,PW
# Processing record 38 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=cabo san lucas,MX
# Processing record 39 | visnes
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=visnes,NO
# Processing record 40 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tiksi,RU
# Processing record 41 | teneguiban
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=teneguiban,PH
# Processing record 42 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ribeira grande,PT
# Processing record 43 | vallenar
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vallenar,CL
# Processing record 44 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sentyabrskiy,RU
# Processing record 45 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vaini,TO
# Processing record 46 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vardo,NO
# Processing record 47 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=grindavik,IS
# Processing record 48 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=illoqqortoormiut,GL
# Processing record 49 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=provideniya,RU
# Processing record 50 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=arraial do cabo,BR
# Processing record 51 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=flinders,AU
# Processing record 52 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ushuaia,AR
# Processing record 53 | bollnas
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bollnas,SE
# Processing record 54 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=alta floresta,BR
# Processing record 55 | puerto madryn
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=puerto madryn,AR
# Processing record 56 | bowen
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bowen,AU
# Processing record 57 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=cape town,ZA
# Processing record 58 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=albany,AU
# Processing record 59 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sur,OM
# Processing record 60 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hobart,AU
# Processing record 61 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=saskylakh,RU
# Processing record 62 | pocosol
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=pocosol,CR
# Processing record 63 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=geraldton,AU
# Processing record 64 | weyburn
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=weyburn,CA
# Processing record 65 | opuwo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=opuwo,NA
# Processing record 66 | marcona
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=marcona,PE
# Processing record 67 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kodiak,US
# Processing record 68 | kaka
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kaka,TM
# Processing record 69 | dwarka
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=dwarka,IN
# Processing record 70 | turayf
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=turayf,SA
# Processing record 71 | benguela
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=benguela,AO
# Processing record 72 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=thompson,CA
# Processing record 73 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=leningradskiy,RU
# Processing record 74 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=jamestown,SH
# Processing record 75 | fukue
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=fukue,JP
# Processing record 76 | novozybkov
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=novozybkov,RU
# Processing record 77 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=havre-saint-pierre,CA
# Processing record 78 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=petropavlovsk-kamchatskiy,RU
# Processing record 79 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bengkulu,ID
# Processing record 80 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=yulara,AU
# Processing record 81 | havoysund
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=havoysund,NO
# Processing record 82 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vao,NC
# Processing record 83 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=codrington,AG
# Processing record 84 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tuktoyaktuk,CA
# Processing record 85 | tynda
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tynda,RU
# Processing record 86 | bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bubaque,GW
# Processing record 87 | samusu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=samusu,WS
# Processing record 88 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=saldanha,ZA
# Processing record 89 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=zhangjiakou,CN
# Processing record 90 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mar del plata,AR
# Processing record 91 | yei
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=yei,SD
# Processing record 92 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=broome,AU
# Processing record 93 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=barrow,US
# Processing record 94 | curup
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=curup,ID
# Processing record 95 | putina
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=putina,PE
# Processing record 96 | svetlyy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=svetlyy,RU
# Processing record 97 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kapaa,US
# Processing record 98 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hermanus,ZA
# Processing record 99 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=meulaboh,ID
# Processing record 100 | bay city
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bay city,US
# Processing record 101 | christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=christchurch,NZ
# Processing record 102 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=port alfred,ZA
# Processing record 103 | maningrida
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=maningrida,AU
# Processing record 104 | camocim
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=camocim,BR
# Processing record 105 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=norman wells,CA
# Processing record 106 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mataura,PF
# Processing record 107 | laurel
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=laurel,US
# Processing record 108 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=faanui,PF
# Processing record 109 | tanout
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tanout,NE
# Processing record 110 | brae
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=brae,GB
# Processing record 111 | kodinsk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kodinsk,RU
# Processing record 112 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=barentsburg,SJ
# Processing record 113 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=la ronge,CA
# Processing record 114 | phonhong
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=phonhong,LA
# Processing record 115 | axim
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=axim,GH
# Processing record 116 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=abu dhabi,AE
# Processing record 117 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=busselton,AU
# Processing record 118 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=katsuura,JP
# Processing record 119 | kingaroy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kingaroy,AU
# Processing record 120 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=fairbanks,US
# Processing record 121 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=talnakh,RU
# Processing record 122 | seoul
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=seoul,KR
# Processing record 123 | bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bonavista,CA
# Processing record 124 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=saint anthony,CA
# Processing record 125 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=saint-augustin,CA
# Processing record 126 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=berdigestyakh,RU
# Processing record 127 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=atuona,PF
# Processing record 128 | port augusta
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=port augusta,AU
# Processing record 129 | aflu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=aflu,DZ
# Processing record 130 | porbandar
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=porbandar,IN
# Processing record 131 | sorong
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sorong,ID
# Processing record 132 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=taolanaro,MG
# Processing record 133 | poya
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=poya,NC
# Processing record 134 | harper
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=harper,LR
# Processing record 135 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lompoc,US
# Processing record 136 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=victoria,SC
# Processing record 137 | krasnovishersk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=krasnovishersk,RU
# Processing record 138 | shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=shimoda,JP
# Processing record 139 | buala
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=buala,SB
# Processing record 140 | west odessa
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=west odessa,US
# Processing record 141 | kjollefjord
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kjollefjord,NO
# Processing record 142 | bud
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bud,NO
# Processing record 143 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lebu,CL
# Processing record 144 | masterton
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=masterton,NZ
# Processing record 145 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=aklavik,CA
# Processing record 146 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=prince rupert,CA
# Processing record 147 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bredasdorp,ZA
# Processing record 148 | caraz
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=caraz,PE
# Processing record 149 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=san cristobal,EC
# Processing record 150 | lowestoft
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lowestoft,GB
# Processing record 151 | nantucket
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nantucket,US
# Processing record 152 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=puerto ayora,EC
# Processing record 153 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nizhneyansk,RU
# Processing record 154 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lasa,CN
# Processing record 155 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=klaksvik,FO
# Processing record 156 | oussouye
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=oussouye,SN
# Processing record 157 | lolua
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lolua,TV
# Processing record 158 | amderma
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=amderma,RU
# Processing record 159 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nikolskoye,RU
# Processing record 160 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sao joao da barra,BR
# Processing record 161 | vanavara
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vanavara,RU
# Processing record 162 | halalo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=halalo,WF
# Processing record 163 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mehamn,NO
# Processing record 164 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sioux lookout,CA
# Processing record 165 | south lake tahoe
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=south lake tahoe,US
# Processing record 166 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=longyearbyen,SJ
# Processing record 167 | grand-santi
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=grand-santi,GF
# Processing record 168 | shingu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=shingu,JP
# Processing record 169 | jining
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=jining,CN
# Processing record 170 | marrakesh
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=marrakesh,MA
# Processing record 171 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hithadhoo,MV
# Processing record 172 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=okhotsk,RU
# Processing record 173 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=castro,CL
# Processing record 174 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hilo,US
# Processing record 175 | imbituba
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=imbituba,BR
# Processing record 176 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vila velha,BR
# Processing record 177 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=dikson,RU
# Processing record 178 | karavukovo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=karavukovo,RS
# Processing record 179 | aitape
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=aitape,PG
# Processing record 180 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tabiauea,KI
# Processing record 181 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kruisfontein,ZA
# Processing record 182 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=clyde river,CA
# Processing record 183 | barao de melgaco
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=barao de melgaco,BR
# Processing record 184 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nome,US
# Processing record 185 | kashary
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kashary,RU
# Processing record 186 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=batagay-alyta,RU
# Processing record 187 | nouakchott
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nouakchott,MR
# Processing record 188 | pochutla
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=pochutla,MX
# Processing record 189 | kochubey
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kochubey,RU
# Processing record 190 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tumannyy,RU
# Processing record 191 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=souillac,MU
# Processing record 192 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hervey bay,AU
# Processing record 193 | tucumcari
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tucumcari,US
# Processing record 194 | suntar
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=suntar,RU
# Processing record 195 | mildura
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mildura,AU
# Processing record 196 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ostrovnoy,RU
# Processing record 197 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=cherskiy,RU
# Processing record 198 | kostomuksha
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kostomuksha,RU
# Processing record 199 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=new norfolk,AU
# Processing record 200 | makaha
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=makaha,US
# Processing record 201 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ahuimanu,US
# Processing record 202 | muros
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=muros,ES
# Processing record 203 | barra
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=barra,BR
# Processing record 204 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=cayenne,GF
# Processing record 205 | okoneshnikovo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=okoneshnikovo,RU
# Processing record 206 | teknaf
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=teknaf,BD
# Processing record 207 | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=itarema,BR
# Processing record 208 | acarau
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=acarau,BR
# Processing record 209 | nuuk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nuuk,GL
# Processing record 210 | kleck
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kleck,BY
# Processing record 211 | houlton
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=houlton,US
# Processing record 212 | oistins
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=oistins,BB
# Processing record 213 | liwale
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=liwale,TZ
# Processing record 214 | lumphat
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lumphat,KH
# Processing record 215 | harindanga
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=harindanga,IN
# Processing record 216 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=san patricio,MX
# Processing record 217 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=guerrero negro,MX
# Processing record 218 | sistranda
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sistranda,NO
# Processing record 219 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=port elizabeth,ZA
# Processing record 220 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=olafsvik,IS
# Processing record 221 | koygorodok
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=koygorodok,RU
# Processing record 222 | kholtoson
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kholtoson,RU
# Processing record 223 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=yar-sale,RU
# Processing record 224 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lorengau,PG
# Processing record 225 | akyab
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=akyab,MM
# Processing record 226 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=upernavik,GL
# Processing record 227 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=severo-kurilsk,RU
# Processing record 228 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=belushya guba,RU
# Processing record 229 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=port lincoln,AU
# Processing record 230 | tamandare
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tamandare,BR
# Processing record 231 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nanortalik,GL
# Processing record 232 | tivaouane
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tivaouane,SN
# Processing record 233 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=deputatskiy,RU
# Processing record 234 | millinocket
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=millinocket,US
# Processing record 235 | ndola
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ndola,ZM
# Processing record 236 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ponta do sol,CV
# Processing record 237 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=chapais,CA
# Processing record 238 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=te anau,NZ
# Processing record 239 | waingapu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=waingapu,ID
# Processing record 240 | byron bay
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=byron bay,AU
# Processing record 241 | koumac
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=koumac,NC
# Processing record 242 | sabha
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sabha,LY
# Processing record 243 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kavieng,PG
# Processing record 244 | nanakuli
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nanakuli,US
# Processing record 245 | ust-charyshskaya pristan
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ust-charyshskaya pristan,RU
# Processing record 246 | veraval
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=veraval,IN
# Processing record 247 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=chokurdakh,RU
# Processing record 248 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=antofagasta,CL
# Processing record 249 | tarudant
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tarudant,MA
# Processing record 250 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sao gabriel da cachoeira,BR
# Processing record 251 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kaitangata,NZ
# Processing record 252 | taraza
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=taraza,CO
# Processing record 253 | kristiinankaupunki
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kristiinankaupunki,FI
# Processing record 254 | ismailia
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ismailia,EG
# Processing record 255 | kongolo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kongolo,CD
# Processing record 256 | san miguel
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=san miguel,BO
# Processing record 257 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lavrentiya,RU
# Processing record 258 | san luis
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=san luis,AR
# Processing record 259 | urumqi
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=urumqi,CN
# Processing record 260 | nishihara
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nishihara,JP
# Processing record 261 | lieksa
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lieksa,FI
# Processing record 262 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=faya,TD
# Processing record 263 | walla walla
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=walla walla,US
# Processing record 264 | chicama
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=chicama,PE
# Processing record 265 | houston
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=houston,CA
# Processing record 266 | shakhrinau
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=shakhrinau,TJ
# Processing record 267 | ciras
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ciras,AF
# Processing record 268 | suffolk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=suffolk,US
# Processing record 269 | wukari
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=wukari,NG
# Processing record 270 | lamu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lamu,KE
# Processing record 271 | bima
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bima,ID
# Processing record 272 | gat
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=gat,LY
# Processing record 273 | numan
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=numan,NG
# Processing record 274 | dawei
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=dawei,MM
# Processing record 275 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=attawapiskat,CA
# Processing record 276 | rolla
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=rolla,US
# Processing record 277 | kapoeta
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kapoeta,SD
# Processing record 278 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=cidreira,BR
# Processing record 279 | cognac
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=cognac,FR
# Processing record 280 | mareeba
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mareeba,AU
# Processing record 281 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=palabuhanratu,ID
# Processing record 282 | kota belud
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kota belud,MY
# Processing record 283 | beyneu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=beyneu,KZ
# Processing record 284 | taonan
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=taonan,CN
# Processing record 285 | kishtwar
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kishtwar,IN
# Processing record 286 | paidha
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=paidha,UG
# Processing record 287 | volosovo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=volosovo,RU
# Processing record 288 | agadez
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=agadez,NE
# Processing record 289 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=coquimbo,CL
# Processing record 290 | cabimas
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=cabimas,VE
# Processing record 291 | ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ahipara,NZ
# Processing record 292 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=pevek,RU
# Processing record 293 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=grand river south east,MU
# Processing record 294 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mahebourg,MU
# Processing record 295 | khorixas
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=khorixas,NA
# Processing record 296 | sharjah
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sharjah,AE
# Processing record 297 | orel-izumrud
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=orel-izumrud,RU
# Processing record 298 | muncie
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=muncie,US
# Processing record 299 | tura
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tura,RU
# Processing record 300 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=plettenberg bay,ZA
# Processing record 301 | nabire
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nabire,ID
# Processing record 302 | jizan
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=jizan,SA
# Processing record 303 | mantua
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mantua,CU
# Processing record 304 | atka
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=atka,RU
# Processing record 305 | hereford
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hereford,US
# Processing record 306 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tilichiki,RU
# Processing record 307 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tasiilaq,GL
# Processing record 308 | bayir
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bayir,JO
# Processing record 309 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=camacha,PT
# Processing record 310 | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tautira,PF
# Processing record 311 | jarjis
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=jarjis,TN
# Processing record 312 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hasaki,JP
# Processing record 313 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=iqaluit,CA
# Processing record 314 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=fortuna,US
# Processing record 315 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bethel,US
# Processing record 316 | warqla
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=warqla,DZ
# Processing record 317 | pingliang
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=pingliang,CN
# Processing record 318 | ascension
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ascension,MX
# Processing record 319 | rawson
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=rawson,AR
# Processing record 320 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=umzimvubu,ZA
# Processing record 321 | prieska
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=prieska,ZA
# Processing record 322 | aleksandrovskiy zavod
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=aleksandrovskiy zavod,RU
# Processing record 323 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=zhigansk,RU
# Processing record 324 | razole
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=karacabey,TR
# Processing record 494 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=beringovskiy,RU
# Processing record 495 | novobirilyussy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=novobirilyussy,RU
# Processing record 496 | malabuyoc
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=malabuyoc,PH
# Processing record 497 | santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=santa maria,CV
# Processing record 498 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=grand gaube,MU
# Processing record 499 | costinesti
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=costinesti,RO
# Processing record 500 | rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=rabo de peixe,PT
# Processing record 501 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=thinadhoo,MV
# Processing record 502 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=svetlogorsk,RU
# Processing record 503 | tamiahua
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tamiahua,MX
# Processing record 504 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=finschhafen,PG
# Processing record 505 | juifang
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=juifang,TW
# Processing record 506 | mezen
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mezen,RU
# Processing record 507 | sayyan
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sayyan,YE
# Processing record 508 | awjilah
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=awjilah,LY
# Processing record 509 | nara
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nara,ML
# Processing record 510 | betsiamites
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=betsiamites,CA
# Processing record 511 | kieta
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kieta,PG
# Processing record 512 | casablanca
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=casablanca,MA
# Processing record 513 | waki
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=waki,JP
# Processing record 514 | williamsburg
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=williamsburg,US
# Processing record 515 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=boyolangu,ID
# Processing record 516 | mao
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mao,TD
# Processing record 517 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tazovskiy,RU
# Processing record 518 | fabriano
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=fabriano,IT
# Processing record 519 | nola
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nola,CF
# Processing record 520 | abeche
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=abeche,TD
# Processing record 521 | mahanoro
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mahanoro,MG
# Processing record 522 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=puerto del rosario,ES
# Processing record 523 | mrirt
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mrirt,MA
# Processing record 524 | bull savanna
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=bull savanna,JM
# Processing record 525 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mount gambier,AU
# Processing record 526 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=egvekinot,RU
# Processing record 527 | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=broken hill,AU
# Processing record 528 | kadaya
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kadaya,RU
# Processing record 529 | las vegas
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=las vegas,US
# Processing record 530 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hami,CN
# Processing record 531 | orangeburg
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=orangeburg,US
# Processing record 532 | ridgecrest
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ridgecrest,US
# Processing record 533 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=naze,JP
# Processing record 534 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sitka,US
# Processing record 535 | karachi
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=karachi,PK
# Processing record 536 | ler
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ler,SD
# Processing record 537 | el sauzal
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=el sauzal,MX
# Processing record 538 | sataua
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sataua,WS
# Processing record 539 | kutoarjo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kutoarjo,ID
# Processing record 540 | andselv
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=andselv,NO
# Processing record 541 | mogadouro
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mogadouro,PT
# Processing record 542 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=pacific grove,US
# Processing record 543 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=rio gallegos,AR
# Processing record 544 | ozgon
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ozgon,KG
# Processing record 545 | cerchezu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=cerchezu,RO
# Processing record 546 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kahului,US
# Processing record 547 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kangaatsiaq,GL
# Processing record 548 | maputo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=maputo,MZ
# Processing record 549 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=dunedin,NZ
# Processing record 550 | amahai
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=amahai,ID
# Processing record 551 | neuquen
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=neuquen,AR
# Processing record 552 | vyartsilya
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vyartsilya,RU
# Processing record 553 | rehoboth
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=rehoboth,NA
# Processing record 554 | loum
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=loum,CM
# Processing record 555 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hambantota,LK
# Processing record 556 | irbil
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=irbil,IQ
# Processing record 557 | ekhabi
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=ekhabi,RU
# Processing record 558 | tallahassee
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tallahassee,US
# Processing record 559 | mulki
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mulki,IN
# Processing record 560 | grimari
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=grimari,CF
# Processing record 561 | pine bluff
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=pine bluff,US
# Processing record 562 | sibenik
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sibenik,HR
# Processing record 563 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=chuy,UY
# Processing record 564 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=margate,ZA
# Processing record 565 | acajutiba
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=acajutiba,BR
# Processing record 566 | uruacu
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=uruacu,BR
# Processing record 567 | mattawa
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mattawa,CA
# Processing record 568 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=sobolevo,RU
# Processing record 569 | karkaralinsk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=karkaralinsk,KZ
# Processing record 570 | kungurtug
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kungurtug,RU
# Processing record 571 | iralaya
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=iralaya,HN
# Processing record 572 | marystown
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=marystown,CA
# Processing record 573 | freeport
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=freeport,BS
# Processing record 574 | khandyga
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=khandyga,RU
# Processing record 575 | lugovoy
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lugovoy,RU
# Processing record 576 | hirara
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=hirara,JP
# Processing record 577 | peace river
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=peace river,CA
# Processing record 578 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=mahibadhoo,MV
# Processing record 579 | iraucuba
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=iraucuba,BR
# Processing record 580 | tukrah
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=tukrah,LY
# Processing record 581 | vaitape
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vaitape,PF
# Processing record 582 | kombissiri
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kombissiri,BF
# Processing record 583 | nieuw amsterdam
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=nieuw amsterdam,SR
# Processing record 584 | batagay
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=batagay,RU
# Processing record 585 | satitoa
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=satitoa,WS
# Processing record 586 | huinan
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=huinan,CN
# Processing record 587 | takaka
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=takaka,NZ
# Processing record 588 | coxim
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=coxim,BR
# Processing record 589 | kenai
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=kenai,US
# Processing record 590 | smithers
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=smithers,CA
# Processing record 591 | vilyuysk
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vilyuysk,RU
# Processing record 592 | armidale
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=armidale,AU
# Processing record 593 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lagoa,PT
# Processing record 594 | lola
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=lola,GN
# Processing record 595 | cedar city
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=cedar city,US
# Processing record 596 | abha
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=abha,SA
# Processing record 597 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=constitucion,MX
# Processing record 598 | labytnangi
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=labytnangi,RU
# Processing record 599 | vredefort
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=vredefort,ZA
# Processing record 600 | chilca
# http://api.openweathermap.org/data/2.5/weather?appid=69ef8279e2a7a2609c2b48d751e407ab&units=imperial&q=chilca,PE
# Done!

# %%
#Removing any cities without data
weather_df = weather_df.dropna(how='any')
#Printing number of cities on the list
print(f"The data frame contains {len(weather_df['City'])} unique cities.")
# Out:
# The data frame contains 540 unique cities.

# %%
# Setting the size of the frame
plt.figure(figsize=(9,6))

# Plot the latitude vs the Max Temp
plt.scatter(x = weather_df['Latitude'], y = weather_df['Max Temp'],
            linewidths = 0.85, edgecolors = 'black', color = 'red', s=35)

# Adding labels to graph
plt.title(f"Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Update the lower and upper ticks for x and y axis
plt.xlim(-80,100)
#y ticks based on high and low *Max temp* +/- 5 for wiggle room
plt.ylim(min(weather_df['Max Temp']) - 5, max(weather_df['Max Temp']) + 5)

plt.show()

# %%
# Setting the size of the frame
plt.figure(figsize=(9,6))

# Plot the lat vs the humidity
plt.scatter(x = weather_df['Latitude'], y = weather_df['Humidity'],
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

# Adding labels to graph
plt.title(f"Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Update the lower and upper ticks for x and y axis
#x is standard min/max latitude coordinates
plt.xlim(-80,100)
#y axis was based on top and bottom percentages, with a 10 point wiggle room
plt.ylim(-10, 110)

plt.show()

# %%
# Setting the size of the frame
plt.figure(figsize=(9,6))

# Plot the lat vs the max temp
plt.scatter(x = weather_df['Latitude'], y = weather_df['Cloudiness'],
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

# Adding labels to graph
plt.title(f"Latitude vs. Cloudiness ({weather_dt})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Update the lower and upper ticks for x and y axis
#x is standard min/max latitude coordinates
plt.xlim(-80,100)
#y axis was based on top and bottom percentages, with a 10 point wiggle room
plt.ylim(-10, 110)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5b40de13e416> in <module>
#       7
#       8 # Adding labels to graph
# ----> 9 plt.title(f"Latitude vs. Cloudiness ({weather_dt})")
#      10 plt.xlabel("Latitude")
#      11 plt.ylabel("Cloudiness (%)")
#
# NameError: name 'weather_dt' is not defined

# %%
# Setting the size of the frame
plt.figure(figsize=(9,6))

# Plot the lat vs the wind speed
plt.scatter(x = weather_df['Latitude'], y = weather_df['Wind Speed'],
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

# Adding labels to graph
plt.title(f"Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Update the lower and upper ticks for x and y axis
#x is standard min/max latitude coordinates
plt.xlim(-80,100)
#y axis, we want above and below by a certain amount. 5 seemed good enough to center data
plt.ylim(-5, max(weather_df['Wind Speed'])+5)

plt.show()

# %%
weather_df.to_csv("../Resources/Weather_data.csv", index=False)

# %%
#Part II
weather_data_file = "../Resources/Weather_data.csv"
weather_df = pd.read_csv(weather_data_file)
weather_data_df = weather_df.drop(["Date"], axis=1)
weather_data_df.head()
# Out:
#         City  Latitude  Longitude  Humidity  Max Temp  Cloudiness  Wind Speed  \
# 0    qaanaaq     77.48     -69.36      78.0     13.41           0        7.02
# 1       hede     33.77     120.25      67.0     72.77          27       11.56
# 2  carnarvon    -24.87     113.63      60.0     75.20           0       19.46
# 3      bluff    -46.60     168.33      83.0     51.01          87       11.99
# 4  tuatapere    -46.13     167.68      83.0     51.01          99       11.99
#
#   Country
# 0      GL
# 1      CN
# 2      AU
# 3      NZ
# 4      NZ

# %%
gmaps.configure(api_key=google_api_key)

# %%
locations = weather_data_df[["Latitude", "Longitude"]]
humidity = weather_data_df["Humidity"].astype(float)
#Set the initial figure
fig = gmaps.figure()
#Create the heatmap figure layer
heatmap_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                   dissipating = False,
                                   max_intensity=6,
                                   point_radius=1)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
narrowed_df = pd.DataFrame(weather_data_df, columns= ["City", "Max Temp", "Wind Speed", "Cloudiness"])
#Standard restrictions given
max_temp = (narrowed_df["Max Temp"] <=80) & (narrowed_df["Max Temp"]>= 70)
wind_speed = narrowed_df["Wind Speed"] < 10
cloudiness = narrowed_df["Cloudiness"] == 0
narrowed_df[max_temp & wind_speed & cloudiness]
# Out:
#             City  Max Temp  Wind Speed  Cloudiness
# 144       jining     76.03        5.77           0
# 176        barra     74.75        9.08           0
# 213        sabha     77.41        6.71           0
# 224     ismailia     77.13        5.39           0
# 248     kishtwar     73.65        2.84           0
# 298      estelle     70.00        6.06           0
# 301       riyadh     77.00        7.18           0
# 384     ajdabiya     70.74        7.81           0
# 388  salinopolis     78.48        9.24           0
# 437       mehran     71.60        4.70           0
# 455      awjilah     73.04        7.31           0
# 468     mahanoro     74.77        4.09           0
# 478   ridgecrest     75.00        1.30           0
# 520       tukrah     72.23        8.66           0

# %%
#Creating a new DataFrame for just hotels 
hotel_df = pd.DataFrame(weather_data_df, columns = ["City", "Country", "Latitude", "Longitude"])
#Adding Hotel Name column to DataFrame
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#         City Country  Latitude  Longitude Hotel Name
# 0    qaanaaq      GL     77.48     -69.36
# 1       hede      CN     33.77     120.25
# 2  carnarvon      AU    -24.87     113.63
# 3      bluff      NZ    -46.60     168.33
# 4  tuatapere      NZ    -46.13     167.68

# %%
#Setting up parameters
location_coordinates = f"{hotel_df['Latitude'][0]}, {hotel_df['Longitude'][0]}"
location_search = "hotel"
location_radius = 5000
location_type = "hotel"

#Inputting parameters in dictionary
params = {
    "location": location_coordinates,
    "keyword": location_search,
    "radius": location_radius,
    "type": location_type,
    "key": google_api_key
}

#Creating the base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url, params=params)

# %%
pprint(response.json(), depth=1)
# Out:
# {'html_attributions': [], 'results': [...], 'status': 'OK'}

# %%
#creates a list to capture hotel_names to insert into dataframe
hotel_name = []

# params dictionary to update each iteration
params2 = {
    "radius": 5000,
    "types": "hotel",
    "keyword": "hotel",
    "key": google_api_key
}

# taken from Airpost_Ratings Example done in class
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Latitude"]
    lng = row["Longitude"]

    # change location each iteration while leaving original params in place
    params2["location"] = f"{lat},{lng}"

    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params2)
    
    # convert to json
    name_address = name_address.json()
    # print(json.dumps(name_address, indent=4, sort_keys=True))
    try:
        hotel_name.append(name_address['results'][0]['name'])
    except IndexError:
        hotel_name.append(np.nan)
hotel_name
# Out:
# ['Qaanaaq Hotel',
#  'Fujian Hotel Sheyang',
#  'Carnarvon Motel',
#  'Foveaux Hotel',
#  'Last Light Lodge',
#  'Lei Thar Gone Guest House',
#  'Hotel Rey Don Felipe Punta Arenas',
#  'Kimberleyland Waterfront Holiday Park | Kununurra Accommodation',
#  'Laguna Beach Hotel & Spa',
#  'Best Western Plus The Ranges Karratha',
#  'LÜDERITZ NEST HOTEL',
#  nan,
#  'Карл Маркс',
#  'Hotel Sunroute Patio Goshogawara',
#  'Obsidian Hotel',
#  'Rosewood Bermuda',
#  'The Explorer Hotel',
#  'The hotel complex "Rus"',
#  'Manuia Beach Resort',
#  'Les Embruns Du Baril',
#  'Auyuittuq Lodge (Inns North)',
#  'Esperance Chalet Village',
#  nan,
#  'Beachfront Voyager Motor Inn',
#  'Pension Bianca & Benoit',
#  'Hôtel Panorama',
#  'Hôtel Georges Faustin Aurat',
#  'Gostinitsa "Zapolyar\'ye"',
#  'Hótel Höfn',
#  'HYATT SALALAH HOTEL',
#  'Welk Resorts Cabo San Lucas - Sirena del Mar',
#  'Park Inn Haugesund Airport',
#  'Arktika',
#  'Quinta Das Buganvílias',
#  'Hotel Cecil',
#  'Paradise First Hotel',
#  'Vardö Apartments',
#  'Harbour View',
#  nan,
#  'HOSTEL A COROA',
#  'Barrack Point Holidays',
#  'Las Hayas Ushuaia Resort',
#  'Scandic',
#  'Floresta Amazonica Hotel',
#  'Dazzler by Wyndham Puerto Madryn',
#  'Whitsunday Sands Resort',
#  'Atlanticview Cape Town Boutique Hotel',
#  'The Beach House at Bayside',
#  'Sur Plaza Hotel',
#  'Salamanca Wharf Hotel',
#  nan,
#  'Chachagua Rainforest Eco Lodge',
#  'The Gerald Apartment Hotel',
#  'Microtel Inn & Suites by Wyndham Weyburn',
#  'Opuwo Country Lodge',
#  'Best Western Kodiak Inn and Convention Center',
#  nan,
#  'The Fern Sattva Resort Dwarka',
#  'Golden Dune Hotel',
#  'Aparthotel Mil Cidades',
#  'Best Western Thompson Hotel & Suites',
#  nan,
#  'Richards Travel Lodge',
#  'GOTO TSUBAKI HOTEL',
#  'Green Park',
#  'Hotel Du Havre',
#  'Bay House',
#  'Mercure Bengkulu',
#  'Sails in the Desert',
#  'Havøysund Hotel & Rorbuer',
#  'OURE TERA beach resort',
#  "Hunter's B&B",
#  'Gostinitsa Safari',
#  'Ponta Anchaca',
#  'Protea Hotel by Marriott Saldanha Bay',
#  'Aodu Hotel',
#  'Presidente Hotel Mar Del Plata',
#  'Kimberley Sands Resort',
#  'Top of the World Hotel',
#  'Hotel Dioba Gite',
#  'Hotel Isla Suasi',
#  'ВИЛА-Н, гостевой дом',
#  'Hilton Garden Inn Kauai Wailua Bay',
#  'One Marine Drive Boutique Hotel',
#  'Hotel Meuligoe',
#  'Courtyard by Marriott Bay City',
#  'Fendalton Park Luxury Accommodation',
#  'Royal St Andrews Hotel',
#  'Dhukurrdji Lodge',
#  'Villa del Mar Praia Hotel',
#  'Heritage Hotel',
#  'Fairfield Inn by Marriott Laurel',
#  'InterContinental Bora Bora Resort Thalasso Spa',
#  nan,
#  'Busta House Hotel',
#  nan,
#  'Pickerel Bay Cabins',
#  'Napakuang Resort',
#  'Ankobra Beach',
#  'Jumeirah At Etihad Towers',
#  'Abbey Beach Resort',
#  'Splash Guest House',
#  'ROOM Motels',
#  'SpringHill Suites by Marriott Fairbanks',
#  'Talnakh Hotel',
#  'K-POP HOTEL Seoul Tower',
#  'Oceanside Cabins',
#  nan,
#  nan,
#  'Hôtel Hiva Oa Hanakee Lodge',
#  'Majestic Oasis Apartments',
#  'Hotel Balaji Palace Porbandar',
#  'Swiss-Belhotel Sorong',
#  nan,
#  "Grands' Guesthouse",
#  'Embassy Suites by Hilton Lompoc Central Coast',
#  'Hilton Seychelles Northolme Resort & Spa',
#  'For you',
#  'Shimoda Tokyu Hotel',
#  'Ghaseali Island Resort',
#  nan,
#  'Hotel Nordkyn',
#  'Pluscamp Bud',
#  'Hostal Plaza Lebu',
#  'Copthorne Hotel & Resort Solway Park Wairarapa',
#  'Sundog Inn',
#  'Crest Hotel',
#  'De Hoop Collection',
#  'IntiRumi Inn',
#  'Sea Side Inn San Cristobal Galapagos',
#  'Hotel Katherine Lowestoft',
#  'White Elephant Nantucket',
#  'Bay House',
#  'Geilin Bed & Breakfast',
#  nan,
#  nan,
#  'Pousada Porto Prime',
#  nan,
#  'Mehamn Arctic Hotel AS',
#  'Sunset Inn & Suites',
#  'Hard Rock Hotel & Casino Lake Tahoe',
#  "Mary-Ann's Polarrigg",
#  'Hotel La Villa Couacou',
#  'Hotel New Palace',
#  'Wanda Realm Jining',
#  'Royal Mansour Marrakech',
#  'Pebbles Inn',
#  'Prozhivaniye V Okhotske',
#  'Casa Barco Chiloe',
#  'Grand Naniloa Hotel Hilo - a DoubleTree by Hilton',
#  'Praia Hotel Imbituba',
#  'Hotel Senac Ilha do Boi',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Naujaaraaluit – Clyde River Hotel',
#  'Tuiuiú Pantanal Hotel',
#  'Noxapaga Suites',
#  'Гостиница N 1',
#  'Batagay-Alyta',
#  'AZALAÏ HOTEL NOUAKCHOTT (MARHABA )',
#  'Hotel Gela',
#  'Gostinitsa Karavan',
#  'Shanti Maurice Resort & Spa',
#  'Oaks Hervey Bay Resort and Spa',
#  'Fairfield Inn & Suites by Marriott Tucumcari',
#  'Gostevoy Dom',
#  'Quality Hotel Mildura Grand',
#  nan,
#  nan,
#  'Guest House Kotiranta',
#  'Tynwald Willow Bend Estate',
#  'Hawaiian Princess Resort',
#  nan,
#  'Hotel La Muradana',
#  'Hotel Barra Palace',
#  'Royal Amazonia',
#  nan,
#  'Milky Resort',
#  'Vila Ybytu Eco Resort',
#  'Hotel Riviera',
#  'Hotel Hans Egede',
#  'Shiretown Inn and Suites',
#  'Sandals Barbados',
#  'Samoma Lodge',
#  'Tat Tai Rapid',
#  nan,
#  'Grand Isla Navidad Resort',
#  'Hotel Los Caracoles',
#  'Hotell Frøya',
#  'Bhotani Lodge',
#  'Við Hafið Guesthouse',
#  nan,
#  nan,
#  'Hotel "Nord House"',
#  'Seeadler Bay Hotel',
#  'Yuzana Aung Hotel',
#  'Café de Upernavik',
#  'Kak Doma',
#  'The Grand Tasman Hotel',
#  'Hotel Coral Beach',
#  'Hotel Kap Farvel',
#  nan,
#  nan,
#  'Baxter Park Inn',
#  'Protea Hotel by Marriott Ndola',
#  'Pedracin Village',
#  'Hôtel Opémiska',
#  'Fiordland Lodge Te Anau',
#  'Padadita Beach Hotel',
#  'Elements of Byron - MGallery',
#  'Karem Bay',
#  'فندق أفريقيا',
#  'Nusa Island Retreat',
#  nan,
#  nan,
#  'The Fern Residency, Somnath',
#  nan,
#  'Hampton by Hilton Antofagasta',
#  'Hotel Uaupes',
#  nan,
#  'Hotel Casa Blanca',
#  'Hotel Alma',
#  'Tolip Alforsan Island Hotel And Spa',
#  'Hôtel Bouger Faire Bouger Rj Kanierra',
#  nan,
#  nan,
#  'Hotel Premium Tower Suites San Luis',
#  'JinJiang International Hotel Urumqi',
#  '百名伽藍',
#  'Hotelli Puustelli',
#  'The FINCH',
#  'Balihai Bungalows',
#  'Sunshine Inn',
#  nan,
#  'Rohi Grand Suites',
#  'Lamu House',
#  "King's Garden",
#  'Numan Hotel',
#  'The Mandolis Hotel and Restaurant',
#  'Holiday Inn Express & Suites Rolla - Univ of Missouri S&T',
#  'Pousada Vila Di Italy',
#  'Le Clos des Pierres Blanches',
#  'Taj on Byrnes Mareeba Luxury Accommodation',
#  'Tang Dynasty Lodge Kota Belud',
#  'HOTEL "AKNUR"',
#  'Jingdu Hotel',
#  'Hotel Phoenix International',
#  'Goli Resort and Vacation Home',
#  'Nairi',
#  nan,
#  'Cond. Playa La Herradura',
#  'Hotel Paradise',
#  'Ahipara Bay Motel',
#  "Munitsipal'naya Gostinitsa",
#  'Holiday Inn Mauritius Mon Tresor',
#  'Damara Mopane Lodge',
#  'The Chedi Al Bait, Sharjah - a GHM hotel',
#  'ZARA Hotel',
#  'Courtyard by Marriott Muncie at Horizon Convention Center',
#  nan,
#  'Sky Villa Boutique Hotel',
#  'Hotel Grand Papua Nabire',
#  nan,
#  'Hotel Mangos De Roques',
#  'Holiday Inn Express Hereford',
#  nan,
#  'Hotel Angmagssalik',
#  'Pestana Porto Santo',
#  nan,
#  '別邸 海と森',
#  'Frobisher Inn',
#  'Bear River Casino Resort',
#  'Courtyard by Marriott Danbury',
#  'IBIS Hotel KongTongXi Road in PingLiang',
#  'Hotel Punta León',
#  'Excelsior River Cottage',
#  'Druzhba',
#  'Gostinichnyy Kompleks Aylgy',
#  'Sterling Palavelli Godavari',
#  nan,
#  'Hotel Tarakan Plaza',
#  nan,
#  'HOTEL Kii',
#  nan,
#  'Hotel Zumrat',
#  nan,
#  nan,
#  'Clássico Hotel',
#  'Premier Hotels & Resorts',
#  'Hotel Misión San Miguel',
#  'Hotel Casa Royale',
#  'Elnio sapnas',
#  nan,
#  'Curubo Hotel',
#  'Harbour Suites',
#  'Namgay General Shop',
#  'Hampton Inn & Suites Harvey/New Orleans West Bank, LA',
#  'Гостиница Байкальская',
#  'Pasyadahan Beach Resort',
#  'Four Seasons Hotel Riyadh At Kingdom Center',
#  "1870's Taş Konak Otel Cafe&Bakery",
#  'Enshi Wulingdu Hotel',
#  'Jiuquan Hotel',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Niyama Private Islands Maldives',
#  'Holiday Inn Express & Suites Kingsport-Meadowview I-26',
#  'Hoteles Pueblo Inn',
#  'Pensão Venus',
#  'Imagination Island',
#  'Palm Spring Resort Hotel Myitkyina',
#  nan,
#  'Hotel Rainha do Vale',
#  'Free Zone Hotel Nouadhibou',
#  'HOSPEDAJE RIVERA',
#  'Colonial Guest House of Fogo',
#  'Apr Paradise',
#  'Hotel Pruski',
#  'Gostinitsa Usvyacha',
#  'Athoma Guest House',
#  'Tristan Auberge',
#  nan,
#  'Hotel Alecrim',
#  nan,
#  'JVL Inn and Cafeteria',
#  'Hotel Vila Gale Touros',
#  'Hotel Los Arcos',
#  'Gostinitsa',
#  'Super secret pirate cove',
#  'Pudong Holiday Hotel',
#  "Pike's Waterfront Lodge",
#  nan,
#  'Hotel Slaviero Essential Porto Velho',
#  'Protea Hotel by Marriott Takoradi Select',
#  'BON Hotel Waterfront Richards Bay',
#  nan,
#  'Quetico Inn (formerly Radisson)',
#  nan,
#  'Woodlands Inn & Suites',
#  nan,
#  'Hotel Selfoss & SPA',
#  nan,
#  'Perobavilla Hotel',
#  'Bulls and Anchor Inn',
#  'Panamericana Hotel Ancud',
#  'Rest Haven Beach Cottages',
#  nan,
#  'Claro Hotel Kendari',
#  'Hotel Goiânia',
#  'Hotel Santo',
#  'Taverna U Dyadi Viti',
#  'Hotel pariwar residency',
#  nan,
#  'Bonthe Holiday Village',
#  'HOTEL CHEZ JIMMY',
#  'Karlsá Lodge',
#  'The Point Coolum Beach - Ocean View Accommodation',
#  'L’Hôtel-Spa Le Suisse',
#  'Executive Paraíso Hotel',
#  'SURYA INN',
#  'Pousada Encanto Abrolhos',
#  'Hotel Arctic',
#  'Samburu Guest House',
#  nan,
#  'Taloa Heights',
#  'Osprey Beach Hotel',
#  'Villa Hontomin',
#  nan,
#  'Best Western Plus Humboldt Bay Inn',
#  'Hotel Apart El Faro',
#  'Hotel Narsaq',
#  'ささやかなおうち串間/高松(貸別荘)',
#  'Holiday Inn Tampico Altamira',
#  nan,
#  'The Griff Motel',
#  'Hotel Bellevue Syrene',
#  'Coral Sea Resort & Casino',
#  'Hôtel Raiatea Lodge',
#  'AKZENT Hotel Berlin Bad Bevensen',
#  'London House',
#  'Almadina Hotel',
#  'Velichko T.p., Gostinitsa',
#  'Sumeya Hotel',
#  nan,
#  'Hotel Concha do Mar',
#  'Hotel Ivaana',
#  'Jatiúca Hotel & Resort',
#  'HOTEL R. SOARES',
#  nan,
#  nan,
#  'Flamingo Villas Boutique Hotel',
#  'Courtyard by Marriott Cleveland Airport South',
#  'Clubhouse Hotel & Suites',
#  'House 7 Resort',
#  'Hotel Dorado',
#  'Casa Rosa Hotel Residence',
#  nan,
#  'Kangcheng Jian Guo International Hotel',
#  'RIDE Surf Resort & Spa',
#  'Black Swan Inn',
#  'Pousada do Amparo',
#  'Casa Rodo 53',
#  'Deep Blue Hotel & Hot Springs',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Allure on Ocean Motel',
#  nan,
#  "Idlers' Rest Beach Hotel",
#  'The Regency Hotel',
#  nan,
#  'Мотель Каприз',
#  'Jinhai New Century Grand Hotel',
#  'Hondaafushi Island Resort',
#  'Carters By The Sea Beachside Apartments, Carters Beach,Westport',
#  "Le Q'Artier",
#  'Xiangxi National Hotel',
#  'Marathon Harbour Inn',
#  nan,
#  'Shangri-La Hotel, Hohhot',
#  'Voi Wildlife Lodge',
#  'Ulvesund FYR',
#  'Fairmont Jasper Park Lodge',
#  'Azura Bermuda',
#  'Chukotka hotel',
#  nan,
#  nan,
#  nan,
#  'Hotel Maritim Skjervøy AS',
#  'Half Moon Bay Lodge',
#  'Westwood Inn Hotel & Indoor',
#  'پارکینگ شهید حججی',
#  'Hotel Emacite Flex',
#  nan,
#  'Otel\' "Medvezh\'ye"',
#  'Hotel Asra',
#  nan,
#  'Gostinitsa',
#  'Bamboo Beachhouse',
#  'Hotel Riu Funana',
#  'LUX Grand Gaube Resort & Villas',
#  'Vox Maris Grand Resort',
#  'Pedras do Mar Resort & SPA',
#  nan,
#  "Otel' Grand Palas",
#  'HOTEL HH URSULA',
#  'Cossam Guest House',
#  'Gostinitsa "Mezen\'"',
#  nan,
#  nan,
#  nan,
#  'Siège social - Station Uapishka',
#  nan,
#  'Four Seasons Hotel Casablanca',
#  'BLUE VILLA ANABUKI',
#  'Westgate Historic Williamsburg Resort',
#  'Crown Victoria Hotel',
#  nan,
#  'ЧУМ HOTEL',
#  'Hotel Ristorante Marchese Del Grillo',
#  nan,
#  'Hotel Cesar',
#  'Bungalow le Prestige',
#  'Hotel El Mirador',
#  "Big Red's",
#  'Park Hotel Mount Gambier',
#  nan,
#  'The Astra',
#  nan,
#  'The STRAT Hotel, Casino & SkyPod',
#  '哈密环球大酒店',
#  'Palmetto Inn & Suites',
#  'SpringHill Suites by Marriott Ridgecrest',
#  '山羊島ホテル',
#  'Aspen Suites Hotel Sitka',
#  'HOTEL MEHRAN',
#  'California Villas & Hotel',
#  'Hotel Sawunggalih Kutoarjo',
#  'Hotel Trindade Coelho',
#  'Lighthouse Lodge & Cottages',
#  'Apart Hotel Austral',
#  nan,
#  'Maui Beach Hotel',
#  nan,
#  'Polana Serena Hotel',
#  'Distinction Dunedin Hotel',
#  'HOTEL ISABELA',
#  'Hotel del Comahue',
#  'Hotelli Joki',
#  'Ochsenwagen Hotel Pension',
#  'Josephina Hotel',
#  'The Peacock Beach Hotel Hambantota',
#  'Divan Erbil Hotel',
#  nan,
#  'Courtyard by Marriott Tallahassee Downtown/Capitol',
#  'Gaurika Residency Lodging and Boarding',
#  'Best Western Presidential Hotel & Suites',
#  'Solaris Dalmatian Stars Homes',
#  'Bertelli Chuí Hotel',
#  'St Michaels Sands Hotel and Restaurant',
#  nan,
#  'Confort Hotel',
#  'Le Voyageur Inn',
#  nan,
#  nan,
#  nan,
#  'Marystown Hotel & Convention Centre',
#  'Island Seas Resort',
#  'Prezidentskaya Gostinitsa',
#  'Quiet Corner Hotel Sharjah',
#  'Grand Bleu Gamin',
#  'Best Western Plus Peace River Hotel & Suites',
#  'Hudhuveli Maldives',
#  'Pousada Blue Marlin',
#  'مصيف مرحبا للعائلات',
#  'InterContinental Le Moana Bora Bora',
#  'Hotel Mitibkieta, Kombissiri',
#  'Tucan Residence',
#  nan,
#  '玛珥湖山庄',
#  'Waitapu Springs B&B',
#  'Faedo Hotel Beira Rio',
#  'Kenai Airport Hotel',
#  'Prestige Hudson Bay Lodge',
#  'Gostinitsa "Mariya"',
#  'Tattersalls Hotel Armidale',
#  'Graciosa Resort - Biosphere Island Hotel',
#  nan,
#  'Courtyard by Marriott Cedar City',
#  'Sarawat Park Hotel & Resort',
#  'Hotel Gobernador',
#  'Priuralye Hotel',
#  nan,
#  'LA CASA DE DON JOAQUIN']

# %%
hotel_df['Hotel Name'] = hotel_name
hotel_df.dropna()
hotel_df.to_csv("../Resources/Hotel_data.csv", index=False)

# %%
#Found this code online
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""

hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
